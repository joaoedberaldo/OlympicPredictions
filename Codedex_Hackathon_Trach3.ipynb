# %% [markdown]
# <a href="https://colab.research.google.com/github/joaoedberaldo/OlympicPredictions/blob/main/Codedex_Hackathon_Trach3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import plotly.express as px
from datetime import datetime

# %%
olympicsAthlete = pd.read_csv('https://raw.githubusercontent.com/joaoedberaldo/OlympicPredictions/main/olympic_athletes.csv')
olympicsMedals = pd.read_csv('https://raw.githubusercontent.com/joaoedberaldo/OlympicPredictions/main/olympic_medals.csv')

olympicsMedals
# Out:
#       discipline_title     slug_game                      event_title  \
# 0              Curling  beijing-2022                    Mixed Doubles
# 1              Curling  beijing-2022                    Mixed Doubles
# 2              Curling  beijing-2022                    Mixed Doubles
# 3              Curling  beijing-2022                    Mixed Doubles
# 4              Curling  beijing-2022                    Mixed Doubles
# ...                ...           ...                              ...
# 21692    Weightlifting   athens-1896  heavyweight - one hand lift men
# 21693    Weightlifting   athens-1896  heavyweight - one hand lift men
# 21694    Weightlifting   athens-1896  heavyweight - two hand lift men
# 21695    Weightlifting   athens-1896  heavyweight - two hand lift men
# 21696    Weightlifting   athens-1896  heavyweight - two hand lift men
#
#       event_gender medal_type participant_type participant_title  \
# 0            Mixed       GOLD         GameTeam             Italy
# 1            Mixed       GOLD         GameTeam             Italy
# 2            Mixed     SILVER         GameTeam            Norway
# 3            Mixed     SILVER         GameTeam            Norway
# 4            Mixed     BRONZE         GameTeam            Sweden
# ...            ...        ...              ...               ...
# 21692          Men     SILVER          Athlete               NaN
# 21693          Men     BRONZE          Athlete               NaN
# 21694          Men       GOLD          Athlete               NaN
# 21695          Men     SILVER          Athlete               NaN
# 21696          Men     BRONZE          Athlete               NaN
#
#                                              athlete_url  \
# 0      https://olympics.com/en/athletes/stefania-cons...
# 1          https://olympics.com/en/athletes/amos-mosaner
# 2      https://olympics.com/en/athletes/kristin-skaslien
# 3      https://olympics.com/en/athletes/magnus-nedreg...
# 4         https://olympics.com/en/athletes/almida-de-val
# ...                                                  ...
# 21692      https://olympics.com/en/athletes/viggo-jensen
# 21693                                                NaN
# 21694      https://olympics.com/en/athletes/viggo-jensen
# 21695  https://olympics.com/en/athletes/launceston-el...
# 21696   https://olympics.com/en/athletes/sotirios-versis
#
#              athlete_full_name   country_name country_code  \
# 0         Stefania CONSTANTINI          Italy           IT
# 1                 Amos MOSANER          Italy           IT
# 2             Kristin SKASLIEN         Norway           NO
# 3           Magnus NEDREGOTTEN         Norway           NO
# 4                Almida DE VAL         Sweden           SE
# ...                        ...            ...          ...
# 21692             Viggo JENSEN        Denmark           DK
# 21693  Alexandros Nikolopoulos         Greece           GR
# 21694             Viggo JENSEN        Denmark           DK
# 21695        Launceston ELLIOT  Great Britain           GB
# 21696          Sotirios VERSIS         Greece           GR
#
#       country_3_letter_code
# 0                       ITA
# 1                       ITA
# 2                       NOR
# 3                       NOR
# 4                       SWE
# ...                     ...
# 21692                   DEN
# 21693                   GRE
# 21694                   DEN
# 21695                   GBR
# 21696                   GRE
#
# [21697 rows x 12 columns]

# %%
## data prep I: data cleaning part one (getting rid of import errors)

olympicsMedals.columns

olympicsMedals_clean= olympicsMedals.drop(['athlete_url','country_code','country_3_letter_code'], axis=1)

olympicsMedals_clean

merged_data = pd.merge(olympicsMedals, olympicsAthlete[['athlete_full_name', 'athlete_year_birth']], on='athlete_full_name', how='left')

# Convert 'date_of_birth' to integers (assuming it is in year format)
merged_data['athlete_year_birth'] = merged_data['athlete_year_birth'].fillna(2000).astype(int)

# Get the current year
current_year_Tokyo = 2021

# Calculate the age of each athlete
merged_data['age'] = current_year_Tokyo - merged_data['athlete_year_birth']

#create data for paris2024
merged_dataParis = merged_data[(merged_data['slug_game'] == "tokyo-2020")].copy()
merged_dataParis['age'] += 3
merged_dataParis['slug_game'] = "paris-2024"

# Filter ages between 24 and 27 inclusive
merged_dataParis_filtered = merged_dataParis[(merged_dataParis['age'] >= 24) & (merged_dataParis['age'] <= 27)]


#merged_dataParis
merged_dataParis_filtered
# Out:
#       discipline_title   slug_game                event_title event_gender  \
# 365           Shooting  paris-2024            Trap Mixed Team        Mixed
# 371           Shooting  paris-2024  50m Rifle 3 Positions Men          Men
# 380           Shooting  paris-2024        10m Air Rifle women        Women
# 381           Shooting  paris-2024        10m Air Rifle women        Women
# 393           Shooting  paris-2024       10m Air Pistol women        Women
# ...                ...         ...                        ...          ...
# 1543            Hockey  paris-2024                        Men          Men
# 1544            Hockey  paris-2024                      Women        Women
# 1545            Hockey  paris-2024                      Women        Women
# 1546            Hockey  paris-2024                      Women        Women
# 1553  Beach Volleyball  paris-2024                        Men          Men
#
#      medal_type participant_type         participant_title  \
# 365      BRONZE         GameTeam  United States of America
# 371        GOLD          Athlete                       NaN
# 380        GOLD          Athlete                       NaN
# 381      SILVER          Athlete                       NaN
# 393      BRONZE          Athlete                       NaN
# ...         ...              ...                       ...
# 1543     BRONZE         GameTeam                     India
# 1544       GOLD         GameTeam               Netherlands
# 1545     SILVER         GameTeam                 Argentina
# 1546     BRONZE         GameTeam             Great Britain
# 1553       GOLD         GameTeam           Mol A./Sorum C.
#
#                                             athlete_url     athlete_full_name  \
# 365   https://olympics.com/en/athletes/madelynn-ann-...   Madelynn Ann BERNAU
# 371    https://olympics.com/en/athletes/changhong-zhang       Changhong ZHANG
# 380          https://olympics.com/en/athletes/qian-yang             Qian YANG
# 381   https://olympics.com/en/athletes/anastasiia-ga...  Anastasiia GALASHINA
# 393       https://olympics.com/en/athletes/ranxin-jiang          Ranxin JIANG
# ...                                                 ...                   ...
# 1543                                                NaN                   NaN
# 1544                                                NaN                   NaN
# 1545                                                NaN                   NaN
# 1546                                                NaN                   NaN
# 1553  https://olympics.com/en/athletes/anders-bernts...   Anders Berntsen MOL
#
#                     country_name country_code country_3_letter_code  \
# 365     United States of America           US                   USA
# 371   People's Republic of China           CN                   CHN
# 380   People's Republic of China           CN                   CHN
# 381                          ROC          ROC                   ROC
# 393   People's Republic of China           CN                   CHN
# ...                          ...          ...                   ...
# 1543                       India           IN                   IND
# 1544                 Netherlands           NL                   NED
# 1545                   Argentina           AR                   ARG
# 1546               Great Britain           GB                   GBR
# 1553                      Norway           NO                   NOR
#
#       athlete_year_birth  age
# 365                 1998   26
# 371                 2000   24
# 380                 2000   24
# 381                 1997   27
# 393                 2000   24
# ...                  ...  ...
# 1543                2000   24
# 1544                2000   24
# 1545                2000   24
# 1546                2000   24
# 1553                1997   27
#
# [463 rows x 14 columns]

# %%
## data prep II: learning about the dataset

olympicsMedals_clean.info()

#spending_clean.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21697 entries, 0 to 21696
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   discipline_title   21697 non-null  object
#  1   slug_game          21697 non-null  object
#  2   event_title        21697 non-null  object
#  3   event_gender       21697 non-null  object
#  4   medal_type         21697 non-null  object
#  5   participant_type   21697 non-null  object
#  6   participant_title  6584 non-null   object
#  7   athlete_full_name  18073 non-null  object
#  8   country_name       21697 non-null  object
# dtypes: object(9)
# memory usage: 1.5+ MB

# %%
olympicsMedals_final= olympicsMedals_clean
olympicsMedals_final= olympicsMedals_final[(olympicsMedals_final['slug_game'] == "tokyo-2020")] #records from tokyo 2020

olympicsMedals_finalTotal = olympicsMedals_final.drop(['athlete_full_name','slug_game','participant_type','participant_title','discipline_title','event_gender','participant_title'], axis=1).drop_duplicates()
total_medals_per_country = olympicsMedals_finalTotal.groupby('country_name').size().reset_index(name='total_medals')
total_medals_per_country['country_name']= total_medals_per_country['country_name'].replace('ROC', 'Russia')
total_medals_sorted = total_medals_per_country.sort_values(by="total_medals", ascending=False)
top_7_countries = total_medals_sorted.head(7)

# Extract the names of the top 7 countries
top_7_countries_list = top_7_countries['country_name'].tolist()



total_each_medals_per_country = olympicsMedals_finalTotal.groupby(['country_name', 'medal_type']).size().reset_index(name='count')
total_each_medals_per_country['country_name']= total_each_medals_per_country['country_name'].replace('ROC', 'Russia')
total_each_medals_sorted = total_each_medals_per_country.sort_values(by="count", ascending=False)
top_7_countries_each_medal = total_each_medals_per_country[total_each_medals_per_country['country_name'].isin(top_7_countries_list)]


#clean team data
olympicsMedals_finalTeam = olympicsMedals_final[(olympicsMedals_final['participant_type'] == "GameTeam")]
olympicsMedals_finalTeam= olympicsMedals_finalTeam.drop(['athlete_full_name','slug_game','participant_type','participant_title'], axis=1)


#clean solo data
olympicsMedals_finalSolo = olympicsMedals_final[(olympicsMedals_final['participant_type'] != "GameTeam")]
olympicsMedals_finalSolo= olympicsMedals_finalSolo.drop(['participant_title','participant_type','slug_game'], axis=1)

#merged_data
merged_dataTokyo = merged_data[(merged_data['slug_game'] == "tokyo-2020")]
merged_data_Year = merged_dataTokyo.drop(['athlete_url','slug_game','participant_type','participant_title','discipline_title','event_gender','country_code','event_title','country_3_letter_code','athlete_full_name','athlete_year_birth'], axis=1)
merged_data_Year['country_name']= merged_data_Year['country_name'].replace('ROC', 'Russia')
top_7_countries_merged_data = merged_data_Year[merged_data_Year['country_name'].isin(top_7_countries_list)]
average_age_per_medal_type = top_7_countries_merged_data.groupby(['country_name', 'medal_type'])['age'].mean().reset_index()
average_age_per_medal_type['age'] = average_age_per_medal_type['age'].round(2)  # Round to two decimal places

average_age_per_Total_medal = merged_data_Year.drop(['country_name'], axis=1)
average_age_per_Total_medal = average_age_per_Total_medal.groupby(['medal_type'])['age'].mean().reset_index()

#paris2024 data

merged_dataParis_Final = merged_dataParis_filtered.drop(['athlete_full_name','slug_game','participant_type','participant_title','discipline_title','event_gender','participant_title'], axis=1).drop_duplicates()
merged_dataParis_Final_Group = merged_dataParis_Final.groupby('country_name').size().reset_index(name='total_medals')
merged_dataParis_Final_Group['country_name']= merged_dataParis_Final_Group['country_name'].replace('ROC', 'Russia')
merged_dataParis_Final_Groupsorted = merged_dataParis_Final_Group.sort_values(by="total_medals", ascending=False)
top_7_countriesPARIS = merged_dataParis_Final_Groupsorted.head(7)


top_7_countriesPARIS

#average_age_per_Total_medal
#average_age_per_Total_medal
#top_7_countries_each_medal
#olympicsMedals_finalTotal
#olympicsMedals_final
#olympicsMedals_finalSolo
#olympicsMedals_finalTeam
# Out:
#                   country_name  total_medals
# 73    United States of America            53
# 27               Great Britain            33
# 55                      Russia            30
# 51  People's Republic of China            29
# 2                    Australia            27
# 38                       Japan            26
# 23                      France            18

# %%
## data analysis part I: statistics

#olympicsMedals_final
olympicsMedals_finalTotal.describe()
#olympicsMedals_finalSolo.describe()
#olympicsMedals_finalTeam.describe()
# Out:
#        event_title medal_type              country_name
# count         1062       1062                      1062
# unique         298          3                        93
# top            Men     BRONZE  United States of America
# freq            30        398                       108

# %%
## data analysis part II: data visualization featuring plotly

fig1 = px.histogram(top_7_countries, x="country_name", y = "total_medals",color="country_name",nbins=25)
fig1.update_layout(bargap=0.21)
fig1.update_layout(title_text='Olympic Tokyo 2021 - Total Medals',xaxis_title='Country Name', yaxis_title='Total Medals')
fig1.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="41390ed6-7bc9-448b-b695-4332a4b3d391" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("41390ed6-7bc9-448b-b695-4332a4b3d391")) {                    Plotly.newPlot(                        "41390ed6-7bc9-448b-b695-4332a4b3d391",                        [{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"country_name=%{x}\u003cbr\u003esum of total_medals=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"United States of America","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"United States of America","nbinsx":25,"offsetgroup":"United States of America","orientation":"v","showlegend":true,"x":["United States of America"],"xaxis":"x","y":[108],"yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"country_name=%{x}\u003cbr\u003esum of total_medals=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"People's Republic of China","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"People's Republic of China","nbinsx":25,"offsetgroup":"People's Republic of China","orientation":"v","showlegend":true,"x":["People's Republic of China"],"xaxis":"x","y":[85],"yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"country_name=%{x}\u003cbr\u003esum of total_medals=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Russia","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Russia","nbinsx":25,"offsetgroup":"Russia","orientation":"v","showlegend":true,"x":["Russia"],"xaxis":"x","y":[68],"yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"country_name=%{x}\u003cbr\u003esum of total_medals=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Great Britain","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Great Britain","nbinsx":25,"offsetgroup":"Great Britain","orientation":"v","showlegend":true,"x":["Great Britain"],"xaxis":"x","y":[64],"yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"country_name=%{x}\u003cbr\u003esum of total_medals=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Japan","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Japan","nbinsx":25,"offsetgroup":"Japan","orientation":"v","showlegend":true,"x":["Japan"],"xaxis":"x","y":[57],"yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"country_name=%{x}\u003cbr\u003esum of total_medals=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Australia","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Australia","nbinsx":25,"offsetgroup":"Australia","orientation":"v","showlegend":true,"x":["Australia"],"xaxis":"x","y":[44],"yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"country_name=%{x}\u003cbr\u003esum of total_medals=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Italy","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Italy","nbinsx":25,"offsetgroup":"Italy","orientation":"v","showlegend":true,"x":["Italy"],"xaxis":"x","y":[40],"yaxis":"y","type":"histogram"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"chorople ...

# %%
fig2 = px.histogram(top_7_countries_each_medal, x="country_name", y="count", color="medal_type", barmode='group', labels={"'value': 'Medal Count', 'variable': 'Medal Type'"}, category_orders={'country_name': top_7_countries_list,'medal_type': ['GOLD', 'SILVER', 'BRONZE']})
fig2.update_layout(title_text='Olympic Tokyo 2021 - Each Medals',xaxis_title='Country Name', yaxis_title='Total by Medals')
fig2.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="077c5251-effa-4926-b8dc-35b0d1cc74fb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("077c5251-effa-4926-b8dc-35b0d1cc74fb")) {                    Plotly.newPlot(                        "077c5251-effa-4926-b8dc-35b0d1cc74fb",                        [{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"medal_type=GOLD\u003cbr\u003ecountry_name=%{x}\u003cbr\u003esum of count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"GOLD","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"GOLD","offsetgroup":"GOLD","orientation":"v","showlegend":true,"x":["Australia","Great Britain","Italy","Japan","People's Republic of China","Russia","United States of America"],"xaxis":"x","y":[16,22,10,27,37,20,34],"yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"medal_type=SILVER\u003cbr\u003ecountry_name=%{x}\u003cbr\u003esum of count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"SILVER","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"SILVER","offsetgroup":"SILVER","orientation":"v","showlegend":true,"x":["Australia","Great Britain","Italy","Japan","People's Republic of China","Russia","United States of America"],"xaxis":"x","y":[7,21,10,14,30,25,41],"yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"medal_type=BRONZE\u003cbr\u003ecountry_name=%{x}\u003cbr\u003esum of count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"BRONZE","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"BRONZE","offsetgroup":"BRONZE","orientation":"v","showlegend":true,"x":["Australia","Great Britain","Italy","Japan","People's Republic of China","Russia","United States of America"],"xaxis":"x","y":[21,21,20,16,18,23,33],"yaxis":"y","type":"histogram"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.22222222 ...

# %%
fig3 = px.histogram(average_age_per_medal_type, x="country_name", y="age", color="medal_type", barmode='group', labels={"'value': 'Medal Count', 'variable': 'Medal Type'"}, category_orders={'country_name': top_7_countries_list, 'medal_type': ['GOLD', 'SILVER', 'BRONZE']})
fig3.update_layout(title_text='Olympic Tokyo 2021 - Age mean',xaxis_title='Country Name', yaxis_title='Mean Age')
fig3.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="449ac607-b64f-4a5f-8473-29a30c2a30f2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("449ac607-b64f-4a5f-8473-29a30c2a30f2")) {                    Plotly.newPlot(                        "449ac607-b64f-4a5f-8473-29a30c2a30f2",                        [{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"medal_type=GOLD\u003cbr\u003ecountry_name=%{x}\u003cbr\u003esum of age=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"GOLD","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"GOLD","offsetgroup":"GOLD","orientation":"v","showlegend":true,"x":["Australia","Great Britain","Italy","Japan","People's Republic of China","Russia","United States of America"],"xaxis":"x","y":[24.21,27.04,27.17,23.93,25.28,24.86,24.42],"yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"medal_type=SILVER\u003cbr\u003ecountry_name=%{x}\u003cbr\u003esum of age=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"SILVER","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"SILVER","offsetgroup":"SILVER","orientation":"v","showlegend":true,"x":["Australia","Great Britain","Italy","Japan","People's Republic of China","Russia","United States of America"],"xaxis":"x","y":[24.25,24.43,29.9,22.21,27.51,25.5,23.89],"yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"medal_type=BRONZE\u003cbr\u003ecountry_name=%{x}\u003cbr\u003esum of age=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"BRONZE","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"BRONZE","offsetgroup":"BRONZE","orientation":"v","showlegend":true,"x":["Australia","Great Britain","Italy","Japan","People's Republic of China","Russia","United States of America"],"xaxis":"x","y":[26.3,25.55,25.43,25.28,28.19,26.44,25.32],"yaxis":"y","type":"histogram"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0. ...

# %%
fig4 = px.bar(average_age_per_Total_medal, x="medal_type", y="age", color="medal_type",
                    labels={'age': 'Mean Age', 'medal_type': 'Medal Type'}, category_orders={'medal_type': ['GOLD', 'SILVER', 'BRONZE']})

# Update layout
fig4.update_layout(title='Olympic Tokyo 2021 - Average Age for Each Medal Type',
                   xaxis_title='Medal Type', yaxis_title='Mean Age')
# Show the figure
fig4.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="652c8ff8-87bf-4dea-8521-451475b1a81f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("652c8ff8-87bf-4dea-8521-451475b1a81f")) {                    Plotly.newPlot(                        "652c8ff8-87bf-4dea-8521-451475b1a81f",                        [{"alignmentgroup":"True","hovertemplate":"Medal Type=%{x}\u003cbr\u003eMean Age=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"GOLD","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"GOLD","offsetgroup":"GOLD","orientation":"v","showlegend":true,"textposition":"auto","x":["GOLD"],"xaxis":"x","y":[25.75132275132275],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Medal Type=%{x}\u003cbr\u003eMean Age=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"SILVER","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"SILVER","offsetgroup":"SILVER","orientation":"v","showlegend":true,"textposition":"auto","x":["SILVER"],"xaxis":"x","y":[26.46965699208443],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Medal Type=%{x}\u003cbr\u003eMean Age=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"BRONZE","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"BRONZE","offsetgroup":"BRONZE","orientation":"v","showlegend":true,"textposition":"auto","x":["BRONZE"],"xaxis":"x","y":[26.360544217687075],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.55555555555555 ...

# %%
fig5 = px.histogram(top_7_countriesPARIS, x="country_name", y = "total_medals",color="country_name",nbins=25)
fig5.update_layout(bargap=0.21)
fig5.update_layout(title_text='Olympic Paris 2024',xaxis_title='Country Name', yaxis_title='Total Athletes between 24 and 27 years')
fig5.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="49d48bf4-2748-4420-b622-9ac746d169ed" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("49d48bf4-2748-4420-b622-9ac746d169ed")) {                    Plotly.newPlot(                        "49d48bf4-2748-4420-b622-9ac746d169ed",                        [{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"country_name=%{x}\u003cbr\u003esum of total_medals=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"United States of America","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"United States of America","nbinsx":25,"offsetgroup":"United States of America","orientation":"v","showlegend":true,"x":["United States of America"],"xaxis":"x","y":[53],"yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"country_name=%{x}\u003cbr\u003esum of total_medals=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Great Britain","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Great Britain","nbinsx":25,"offsetgroup":"Great Britain","orientation":"v","showlegend":true,"x":["Great Britain"],"xaxis":"x","y":[33],"yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"country_name=%{x}\u003cbr\u003esum of total_medals=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Russia","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Russia","nbinsx":25,"offsetgroup":"Russia","orientation":"v","showlegend":true,"x":["Russia"],"xaxis":"x","y":[30],"yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"country_name=%{x}\u003cbr\u003esum of total_medals=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"People's Republic of China","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"People's Republic of China","nbinsx":25,"offsetgroup":"People's Republic of China","orientation":"v","showlegend":true,"x":["People's Republic of China"],"xaxis":"x","y":[29],"yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"country_name=%{x}\u003cbr\u003esum of total_medals=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Australia","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Australia","nbinsx":25,"offsetgroup":"Australia","orientation":"v","showlegend":true,"x":["Australia"],"xaxis":"x","y":[27],"yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"country_name=%{x}\u003cbr\u003esum of total_medals=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Japan","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Japan","nbinsx":25,"offsetgroup":"Japan","orientation":"v","showlegend":true,"x":["Japan"],"xaxis":"x","y":[26],"yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"country_name=%{x}\u003cbr\u003esum of total_medals=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"France","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"France","nbinsx":25,"offsetgroup":"France","orientation":"v","showlegend":true,"x":["France"],"xaxis":"x","y":[18],"yaxis":"y","type":"histogram"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choro ...
